# %%
import pandas as pd

# %%
visa_df=pd.DataFrame()
visa_df
type(visa_df)
# Out:
# pandas.core.frame.DataFrame

# %%
r"C:\Users\Uddhava\Documents\Visadataset.csv"
# Out:
# 'C:\\Users\\Uddhava\\Documents\\Visadataset.csv'

# %%
path=r"C:\Users\Uddhava\Documents\Visadataset.csv"
pd.read_csv(path)
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# 3                         N               98         1897
# 4                         N             1082         2005
# ...                     ...              ...          ...
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 1                Northeast       83425.6500         Year                  Y
# 2                     West      122996.8600         Year                  Y
# 3                     West       83434.0300         Year                  Y
# 4                    South      149907.3900         Year                  Y
# ...                    ...              ...          ...                ...
# 25475                South       77092.5700         Year                  Y
# 25476            Northeast      279174.7900         Year                  Y
# 25477                South      146298.8500         Year                  N
# 25478                 West       86154.7700         Year                  Y
# 25479              Midwest       70876.9100         Year                  Y
#
#       case_status
# 0          Denied
# 1       Certified
# 2          Denied
# 3          Denied
# 4       Certified
# ...           ...
# 25475   Certified
# 25476   Certified
# 25477   Certified
# 25478   Certified
# 25479   Certified
#
# [25480 rows x 12 columns]

# %%
visa_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Empty DataFrame

# %%
visa_df.dtypes
visa_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
visa_df=pd.read_csv(r"C:\Users\Uddhava\Documents\Visadataset.csv")
visa_df.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# 1       83425.6500         Year                  Y   Certified
# 2      122996.8600         Year                  Y      Denied
# 3       83434.0300         Year                  Y      Denied
# 4      149907.3900         Year                  Y   Certified

# %%
visa_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25480 entries, 0 to 25479
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   case_id                25480 non-null  object
#  1   continent              25480 non-null  object
#  2   education_of_employee  25480 non-null  object
#  3   has_job_experience     25480 non-null  object
#  4   requires_job_training  25480 non-null  object
#  5   no_of_employees        25480 non-null  int64
#  6   yr_of_estab            25480 non-null  int64
#  7   region_of_employment   25480 non-null  object
#  8   prevailing_wage        25480 non-null  float64
#  9   unit_of_wage           25480 non-null  object
#  10  full_time_position     25480 non-null  object
#  11  case_status            25480 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 2.3+ MB

# %%
visa_df['continent'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
#           ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
# Name: continent, Length: 25480, dtype: object>

# %%
cdf=visa_df['continent'].value_counts()
cdf
# Out:
# continent
# Asia             16861
# Europe            3732
# North America     3292
# South America      852
# Africa             551
# Oceania            192
# Name: count, dtype: int64

# %%
dir(cdf)
type(cdf)
# Out:
# pandas.core.series.Series

# %%
cdf.keys()
# Out:
# Index(['Asia', 'Europe', 'North America', 'South America', 'Africa',
#        'Oceania'],
#       dtype='object', name='continent')

# %%
continents=visa_df['continent'].unique()
count=[]
for i in visa_df['continent'].unique():
    con=visa_df['continent']==i
    count.append(len(visa_df[con]))

cols=['continent','Number of Applicants']
continents_df=pd.DataFrame(zip(continents,count),
                           columns=cols)
continents_df.to_csv('continents_df.csv',index=False
# Out:
#   Cell In[13], line 11
#
#     ^
# SyntaxError: incomplete input

# %%
cdf.values

# %%
cdf.values()

# %%
keys=cdf.keys()
values=cdf.values
pd.DataFrame(zip(keys.values))

# %%
cdf=visa_df['continent'].value_counts()
keys=cdf.keys()
values=cdf.values
cols=['Lables','count']
df=pd.DataFrame(zip(keys,values),
                columns=cols)
df.to_csv('continents.csv',index=False)

# %%
cdf=visa_df['education_of_employee'].value_counts()
keys=cdf.keys()
values=cdf.values
cols=['lables','count']
df=pd.DataFrame(zip(keys,values),
                columns=cols)
df.to_csv('education_of_employee.csv',index=False)

# %%
for i in cat_columns[1:]:
    cdf=visa_df[i].value_counts()
    keys=cdf.keys()
    values=cdf.values
    cols=['Lables','Count']
    df=pd.DataFrame(zip(keys,values),
                    columns=cols)
    path=r"C:\Users\Uddhava\Documents\Visadataset.csv"
    df.to_csv(f"{path}\\{i}.csv",index=False)

# %%
cdf=visa_df['continent'].value_counts()
cdf

# %%
dir(cdf)

# %%
cdf.keys()

# %%
type(cdf)

# %%
values=cdf.values

# %%
keys=cdf.keys()

# %%
values=cdf.values

# %%
pd.DataFrame(zip(keys,values))

# %%
cdf=visa_df['continent'].value_counts()
keys=cdf.keys()
values=cdf.values
cols=['Lables','Count']
pd.DataFrame(zip(keys,values),
             columns=cols)
# df.to_csv('Continent.csv',index=False)

# %%
cdf=visa_df['continent'].value_counts()
keys=cdf.keys()
values=cdf.values
cols=['Lables','Count']
df=pd.DataFrame(zip(keys,values),
             columns=cols)
df.to_csv('Continent.csv',index=False)

# %%
cat_columns[1:]

# %%
cdf=visa_df['education_of_employee'].value_counts()
keys=cdf.keys()
values=cdf.values
cols=['Lables','Count']
df=pd.DataFrame(zip(keys,values),
             columns=cols)
df.to_csv('education_of_employee',index=False)

cdf=visa_df['continent'].value_counts()
keys=cdf.keys()
values=cdf.values
cols=['Lables','Count']
df=pd.DataFrame(zip(keys,values),
             columns=cols)
df.to_csv('Continent.csv',index=False)
cdf=visa_df['continent'].value_counts()
keys=cdf.keys()
values=cdf.values
cols=['Lables','Count']
df=pd.DataFrame(zip(keys,values),
             columns=cols)
df.to_csv('Continent.csv',index=False)
cdf=visa_df['continent'].value_counts()
keys=cdf.keys()
values=cdf.values
cols=['Lables','Count']
df=pd.DataFrame(zip(keys,values),
             columns=cols)
df.to_csv('Continent.csv',index=False)
cdf=visa_df['continent'].value_counts()
keys=cdf.keys()
values=cdf.values
cols=['Lables','Count']
df=pd.DataFrame(zip(keys,values),
             columns=cols)
df.to_csv('Continent.csv',index=False)
cdf=visa_df['continent'].value_counts()
keys=cdf.keys()
values=cdf.values
cols=['Lables','Count']
df=pd.DataFrame(zip(keys,values),
             columns=cols)
df.to_csv('Continent.csv',index=False)
cdf=visa_df['continent'].value_counts()
keys=cdf.keys()
values=cdf.values
cols=['Lables','Count']
df=pd.DataFrame(zip(keys,values),
             columns=cols)
df.to_csv('Continent.csv',index=False)
cdf=visa_df['continent'].value_counts()
keys=cdf.keys()
values=cdf.values
cols=['Lables','Count']
df=pd.DataFrame(zip(keys,values),
             columns=cols)
df.to_csv('Continent.csv',index=False)

# %%
import pandas as pd

# %%
path=r"C:\Users\Uddhava\Documents\Visadataset.csv"
pd.read_csv(path)
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# 3                         N               98         1897
# 4                         N             1082         2005
# ...                     ...              ...          ...
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 1                Northeast       83425.6500         Year                  Y
# 2                     West      122996.8600         Year                  Y
# 3                     West       83434.0300         Year                  Y
# 4                    South      149907.3900         Year                  Y
# ...                    ...              ...          ...                ...
# 25475                South       77092.5700         Year                  Y
# 25476            Northeast      279174.7900         Year                  Y
# 25477                South      146298.8500         Year                  N
# 25478                 West       86154.7700         Year                  Y
# 25479              Midwest       70876.9100         Year                  Y
#
#       case_status
# 0          Denied
# 1       Certified
# 2          Denied
# 3          Denied
# 4       Certified
# ...           ...
# 25475   Certified
# 25476   Certified
# 25477   Certified
# 25478   Certified
# 25479   Certified
#
# [25480 rows x 12 columns]

# %%
import numpy as np

# %%
df_num = visa_df.select_dtypes(include =[np.int64, np.float64])

# %%
df_cat= visa_df.select_dtypes(include =[object])

# %%
df_num
# Out:
#        no_of_employees  yr_of_estab  prevailing_wage
# 0                14513         2007         592.2029
# 1                 2412         2002       83425.6500
# 2                44444         2008      122996.8600
# 3                   98         1897       83434.0300
# 4                 1082         2005      149907.3900
# ...                ...          ...              ...
# 25475             2601         2008       77092.5700
# 25476             3274         2006      279174.7900
# 25477             1121         1910      146298.8500
# 25478             1918         1887       86154.7700
# 25479             3195         1960       70876.9100
#
# [25480 rows x 3 columns]

# %%
df_cat
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training region_of_employment unit_of_wage  \
# 0                         N                 West         Hour
# 1                         N            Northeast         Year
# 2                         Y                 West         Year
# 3                         N                 West         Year
# 4                         N                South         Year
# ...                     ...                  ...          ...
# 25475                     Y                South         Year
# 25476                     N            Northeast         Year
# 25477                     N                South         Year
# 25478                     Y                 West         Year
# 25479                     N              Midwest         Year
#
#       full_time_position case_status
# 0                      Y      Denied
# 1                      Y   Certified
# 2                      Y      Denied
# 3                      Y      Denied
# 4                      Y   Certified
# ...                  ...         ...
# 25475                  Y   Certified
# 25476                  Y   Certified
# 25477                  N   Certified
# 25478                  Y   Certified
# 25479                  Y   Certified
#
# [25480 rows x 9 columns]

# %%
visa_df.dtypes
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %%
for i in cat_columns[1:]:
    cdf=visa_df[i].value_counts()
    keys=cdf.keys()
    values=cdf.values
    cols=['Lables','Count']
    df=pd.DataFrame(zip(keys,values),
                 columns=cols)
    path=r"C:\Users\Uddhava\Documents\ValueCounts_df"
    df.to_csv(f"{path}\\{i}.csv",index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 for i in cat_columns[1:]:
#       2     cdf=visa_df[i].value_counts()
#       3     keys=cdf.keys()
#
# NameError: name 'cat_columns' is not defined

# %%
visa_df.head()

# %%
import pandas as pd


path = r"C:\Users\Uddhava\Documents\Visadataset.csv"

for i in cat_columns[1:]:
    
    cdf = visa_df[i].value_counts()
    
    df = pd.DataFrame({
        'Labels': cdf.index, 
        'Count': cdf.values
    })
    
  
    df.to_csv(f"{path}\\{i}.csv", index=False)
# Out:
#   Cell In[28], line 16
#     df.to_csv(f"{path}\\{i}.csv", index=False)
#                                  ^
# SyntaxError: invalid non-printable character U+00A0

# %%
import pandas as pd

# Define the path to the main CSV file and the output directory
main_csv_path = r"C:\Users\Uddhava\Documents\Visadataset.csv"
output_directory = r"C:\Users\Uddhava\Documents"

# Read the main CSV file into a DataFrame
visa_df = pd.read_csv(main_csv_path)

# List of categorical columns
cat_columns = visa_df.select_dtypes(include=['object', 'category']).columns

# Iterate over the categorical columns and create separate CSV files for each
for i in cat_columns[1:]:
    cdf = visa_df[i].value_counts()
    df = pd.DataFrame({
        'Labels': cdf.index, 
        'Count': cdf.values
    })
    df.to_csv(f"{output_directory}\\{i}.csv", index=False)
# Out:
#   Cell In[29], line 20
#     df.to_csv(f"{output_directory}\\{i}.csv", index=False)
#                                              ^
# SyntaxError: invalid non-printable character U+00A0

# %%
# Example definition of cat_columns
cat_columns = visa_df.select_dtypes(include=['object']).columns

for i in cat_columns[1:]:
    cdf = visa_df[i].value_counts()
    keys = cdf.keys()
    # Further code using cdf and keys

# %%
cdf
# Out:
# case_status
# Certified    17018
# Denied        8462
# Name: count, dtype: int64

# %%
keys
# Out:
# Index(['Certified', 'Denied'], dtype='object', name='case_status')
