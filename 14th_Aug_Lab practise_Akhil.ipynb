# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
visa_df = pd.read_csv(r"C:\Users\Uddhava\Documents\Visadataset.csv", sep =( ','))
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
cat_columns=visa_df.select_dtypes(include='object').columns

# %%
num_columns=visa_df.select_dtypes(exclude='object').columns

# %%
df = pd.DataFrame(visa_df)

# %%
labels = df.columns.tolist()

# %%
print("Labels:", labels)
# Out:
# Labels: ['case_id', 'continent', 'education_of_employee', 'has_job_experience', 'requires_job_training', 'no_of_employees', 'yr_of_estab', 'region_of_employment', 'prevailing_wage', 'unit_of_wage', 'full_time_position', 'case_status']

# %%
target_labels = df['continent'].unique()
target_labels
# Out:
# array(['Asia', 'Africa', 'North America', 'Europe', 'South America',
#        'Oceania'], dtype=object)

# %%
cat_columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
num_columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
import pandas as pd

def convert_categorical_columns(df, cat_columns):
   
    label_mappings = {}

    for col in cat_columns:
       
        unique_labels = df[col].unique()
        
        label_dict = {label: num for num, label in enumerate(unique_labels)}
      
        label_mappings[col] = label_dict
        
        df[col] = df[col].map(label_dict)
    
    return df, label_mappings

# %%
cat_columns = ['case_id', 'continent']
df, mappings = convert_categorical_columns(df, cat_columns)

# %%
df
# Out:
#        case_id  continent education_of_employee has_job_experience  \
# 0            0          0           High School                  N
# 1            1          0              Master's                  Y
# 2            2          0            Bachelor's                  N
# 3            3          0            Bachelor's                  N
# 4            4          1              Master's                  Y
# ...        ...        ...                   ...                ...
# 25475    25475          0            Bachelor's                  Y
# 25476    25476          0           High School                  Y
# 25477    25477          0              Master's                  Y
# 25478    25478          0              Master's                  Y
# 25479    25479          0            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
mappings
# Out:
# {'case_id': {'EZYV01': 0,
#   'EZYV02': 1,
#   'EZYV03': 2,
#   'EZYV04': 3,
#   'EZYV05': 4,
#   'EZYV06': 5,
#   'EZYV07': 6,
#   'EZYV08': 7,
#   'EZYV09': 8,
#   'EZYV10': 9,
#   'EZYV11': 10,
#   'EZYV12': 11,
#   'EZYV13': 12,
#   'EZYV14': 13,
#   'EZYV15': 14,
#   'EZYV16': 15,
#   'EZYV17': 16,
#   'EZYV18': 17,
#   'EZYV19': 18,
#   'EZYV20': 19,
#   'EZYV21': 20,
#   'EZYV22': 21,
#   'EZYV23': 22,
#   'EZYV24': 23,
#   'EZYV25': 24,
#   'EZYV26': 25,
#   'EZYV27': 26,
#   'EZYV28': 27,
#   'EZYV29': 28,
#   'EZYV30': 29,
#   'EZYV31': 30,
#   'EZYV32': 31,
#   'EZYV33': 32,
#   'EZYV34': 33,
#   'EZYV35': 34,
#   'EZYV36': 35,
#   'EZYV37': 36,
#   'EZYV38': 37,
#   'EZYV39': 38,
#   'EZYV40': 39,
#   'EZYV41': 40,
#   'EZYV42': 41,
#   'EZYV43': 42,
#   'EZYV44': 43,
#   'EZYV45': 44,
#   'EZYV46': 45,
#   'EZYV47': 46,
#   'EZYV48': 47,
#   'EZYV49': 48,
#   'EZYV50': 49,
#   'EZYV51': 50,
#   'EZYV52': 51,
#   'EZYV53': 52,
#   'EZYV54': 53,
#   'EZYV55': 54,
# ...

# %%
# Step 1: Automatically get the unique labels
#We can use the pd.Series.unique() method to get unique labels from a categorical column.

#Step 2: Create a dictionary to map the numbers with labels
#Using the unique labels, we can create a dictionary that maps each label to a unique number.

#Step 3: Apply the mapping to the categorical column
#Finally, we can use the map method to apply this dictionary to the categorical columns.

#Final Function
#Let's create a function that does all of the above.
